# %% [markdown]
# # Data Collection System Test Notebook (2025 Season)
#
# **Project:** Hank's Tank MLB Data Platform
# **Component:** Data Collection Prototype
#
# This notebook serves as a proof-of-concept for the automated data collection system defined in `docs/DATA_COLLECTION_SYSTEM_DESIGN.md`.
# We will validate the specific API endpoints, parameters, and response structures required to build our historical database.
#
# **Objectives:**
# 1. Verify connectivity to MLB Stats API and Baseball Savant.
# 2. Validate that critical parameters (like `qualified=false`) return the expected data volume.
# 3. Inspect JSON response structures to ensure our schema mapping is correct.
# 4. Test data availability for a sample date in the 2025 season.
#
# **Test Date:** May 15, 2025 (Selected as a typical regular season day with a full slate of games)

# %%
# %pip install pybaseball
# Out:
# Collecting pybaseball
#   Using cached pybaseball-2.2.7-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.13.0 in /Users/VTNX82W/Documents/personalDev/hanks_tank_ml/.venv/lib/python3.13/site-packages (from pybaseball) (2.4.0)
# Requirement already satisfied: pandas>=1.0.3 in /Users/VTNX82W/Documents/personalDev/hanks_tank_ml/.venv/lib/python3.13/site-packages (from pybaseball) (2.3.3)
# Collecting beautifulsoup4>=4.4.0 (from pybaseball)
#   Downloading beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: requests>=2.18.1 in /Users/VTNX82W/Documents/personalDev/hanks_tank_ml/.venv/lib/python3.13/site-packages (from pybaseball) (2.32.5)
# Collecting lxml>=4.2.1 (from pybaseball)
#   Downloading lxml-6.0.2-cp313-cp313-macosx_10_13_universal2.whl.metadata (3.6 kB)
# Requirement already satisfied: pyarrow>=1.0.1 in /Users/VTNX82W/Documents/personalDev/hanks_tank_ml/.venv/lib/python3.13/site-packages (from pybaseball) (22.0.0)
# Collecting pygithub>=1.51 (from pybaseball)
#   Downloading pygithub-2.8.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting scipy>=1.4.0 (from pybaseball)
#   Downloading scipy-1.16.3-cp313-cp313-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting matplotlib>=2.0.0 (from pybaseball)
#   Downloading matplotlib-3.10.8-cp313-cp313-macosx_11_0_arm64.whl.metadata (52 kB)
# Collecting tqdm>=4.50.0 (from pybaseball)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting attrs>=20.3.0 (from pybaseball)
#   Downloading attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4>=4.4.0->pybaseball)
#   Downloading soupsieve-2.8.1-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/VTNX82W/Documents/personalDev/hanks_tank_ml/.venv/lib/python3.13/site-packages (from beautifulsoup4>=4.4.0->pybaseball) (4.15.0)
# Collecting contourpy>=1.0.1 (from matplotlib>=2.0.0->pybaseball)
#   Using cached contourpy-1.3.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib>=2.0.0->pybaseball)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=2.0.0->pybaseball)
#   Downloading fonttools-4.61.1-cp313-cp313-macosx_10_13_universal2.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=2.0.0->pybaseball)
#   Using cached kiwisolver-1.4.9-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/VTNX82W/Documents/personalDev/hanks_tank_ml/.venv/lib/python3.13/site-packages (from matplotlib>=2.0.0->pybaseball) (25.0)
# Collecting pillow>=8 (from matplotlib>=2.0.0->pybaseball)
#   Downloading pillow-12.0.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib>=2.0.0->pybaseball)
#   Downloading pyparsing-3.3.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/VTNX82W/Documents/personalDev/hanks_tank_ml/.venv/lib/python3.13/site-packages (from matplotlib>=2.0.0->pybaseball) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/VTNX82W/Documents/personalDev/hanks_tank_ml/.venv/lib/python3.13/site-packages (from pandas>=1.0.3->pybaseball) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/VTNX82W/Documents/personalDev/hanks_tank_ml/.venv/lib/python3.13/site-packages (from pandas>=1.0.3->pybaseball) (2025.3)
# Collecting pynacl>=1.4.0 (from pygithub>=1.51->pybaseball)
#   Downloading pynacl-1.6.1-cp38-abi3-macosx_10_10_universal2.whl.metadata (9.8 kB)
# Collecting pyjwt>=2.4.0 (from pyjwt[crypto]>=2.4.0->pygithub>=1.51->pybaseball)
#   Using cached PyJWT-2.10.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/VTNX82W/Documents/personalDev/hanks_tank_ml/.venv/lib/python3.13/site-packages (from pygithub>=1.51->pybaseball) (2.6.2)
# Collecting cryptography>=3.4.0 (from pyjwt[crypto]>=2.4.0->pygithub>=1.51->pybaseball)
#   Downloading cryptography-46.0.3-cp311-abi3-macosx_10_9_universal2.whl.metadata (5.7 kB)
# Collecting cffi>=2.0.0 (from cryptography>=3.4.0->pyjwt[crypto]>=2.4.0->pygithub>=1.51->pybaseball)
#   Downloading cffi-2.0.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.6 kB)
# Collecting pycparser (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.4.0->pygithub>=1.51->pybaseball)
#   Downloading pycparser-2.23-py3-none-any.whl.metadata (993 bytes)
# Requirement already satisfied: six>=1.5 in /Users/VTNX82W/Documents/personalDev/hanks_tank_ml/.venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->pybaseball) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/VTNX82W/Documents/personalDev/hanks_tank_ml/.venv/lib/python3.13/site-packages (from requests>=2.18.1->pybaseball) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/VTNX82W/Documents/personalDev/hanks_tank_ml/.venv/lib/python3.13/site-packages (from requests>=2.18.1->pybaseball) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/VTNX82W/Documents/personalDev/hanks_tank_ml/.venv/lib/python3.13/site-packages (from requests>=2.18.1->pybaseball) (2025.11.12)
# Using cached pybaseball-2.2.7-py3-none-any.whl (426 kB)
# Downloading attrs-25.4.0-py3-none-any.whl (67 kB)
# Downloading beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Downloading lxml-6.0.2-cp313-cp313-macosx_10_13_universal2.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 23.7 MB/s  0:00:00 eta 0:00:01
# Downloading matplotlib-3.10.8-cp313-cp313-macosx_11_0_arm64.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 23.4 MB/s  0:00:00 eta 0:00:01
# Using cached contourpy-1.3.3-cp313-cp313-macosx_11_0_arm64.whl (274 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp313-cp313-macosx_10_13_universal2.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 51.2 MB/s  0:00:00
# Using cached kiwisolver-1.4.9-cp313-cp313-macosx_11_0_arm64.whl (64 kB)
# Downloading pillow-12.0.0-cp313-cp313-macosx_11_0_arm64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 38.0 MB/s  0:00:00
# Downloading pygithub-2.8.1-py3-none-any.whl (432 kB)
# Using cached PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Downloading cryptography-46.0.3-cp311-abi3-macosx_10_9_universal2.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 35.1 MB/s  0:00:00
# Downloading cffi-2.0.0-cp313-cp313-macosx_11_0_arm64.whl (181 kB)
# Downloading pynacl-1.6.1-cp38-abi3-macosx_10_10_universal2.whl (387 kB)
# Downloading pyparsing-3.3.1-py3-none-any.whl (121 kB)
# Downloading scipy-1.16.3-cp313-cp313-macosx_14_0_arm64.whl (20.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 34.6 MB/s  0:00:00 eta 0:00:01
# Downloading soupsieve-2.8.1-py3-none-any.whl (36 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading pycparser-2.23-py3-none-any.whl (118 kB)
# Installing collected packages: tqdm, soupsieve, scipy, pyparsing, pyjwt, pycparser, pillow, lxml, kiwisolver, fonttools, cycler, contourpy, attrs, matplotlib, cffi, beautifulsoup4, pynacl, cryptography, pygithub, pybaseball
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20/20 [pybaseball]0 [pybaseball]up4]
# Successfully installed attrs-25.4.0 beautifulsoup4-4.14.3 cffi-2.0.0 contourpy-1.3.3 cryptography-46.0.3 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 lxml-6.0.2 matplotlib-3.10.8 pillow-12.0.0 pybaseball-2.2.7 pycparser-2.23 pygithub-2.8.1 pyjwt-2.10.1 pynacl-1.6.1 pyparsing-3.3.1 scipy-1.16.3 soupsieve-2.8.1 tqdm-4.67.1

# %%
import requests
import pandas as pd
import json
from datetime import datetime
import time
import urllib3

# Disable SSL warnings for testing
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# Configuration
BASE_URL = "https://statsapi.mlb.com/api/v1"
TEST_DATE = "2025-05-15"

def print_structure(d, indent=0):
    """
    Recursively prints the structure of a dictionary/list with types and values.
    """
    spacing = '  ' * indent
    if isinstance(d, dict):
        for key, value in d.items():
            if isinstance(value, dict):
                print(f"{spacing}{key} (dict):")
                print_structure(value, indent + 1)
            elif isinstance(value, list):
                print(f"{spacing}{key} (list) [{len(value)} items]:")
                if value:
                    print(f"{spacing}  Sample item:")
                    print_structure(value[0], indent + 2)
            else:
                print(f"{spacing}{key}: {value} ({type(value).__name__})")
    elif isinstance(d, list):
        print(f"{spacing}List [{len(d)} items]:")
        if d:
            print(f"{spacing}  Sample item:")
            print_structure(d[0], indent + 1)
    else:
        print(f"{spacing}{d} ({type(d).__name__})")

def print_json_summary(data, keys_to_show=None):
    """Helper to print JSON structure without flooding the output"""
    if isinstance(data, dict):
        print(f"Keys: {list(data.keys())}")
        if keys_to_show:
            subset = {k: data[k] for k in keys_to_show if k in data}
            print(json.dumps(subset, indent=2))
    elif isinstance(data, list):
        print(f"List Length: {len(data)}")
        if len(data) > 0:
            print("First Item Keys:", list(data[0].keys()))

# %% [markdown]
# ## 1. Schedule Endpoint Test
#
# **Goal:** Identify all games played on a specific date to drive the rest of the collection process.
#
# **Endpoint:** `/schedule`
#
# **Key Parameters:**
# - `sportId=1`: Filters for MLB games only.
# - `hydrate=team,linescore,flags,venue,decisions`: This is crucial. It "hydrates" the response with extra details that usually require separate API calls. We get venue info, final scores, and winning/losing pitchers in a single request.
#
# **Expected Output:** A list of game objects containing the `gamePk` (unique ID) which is required for fetching detailed game feeds.

# %%
url = f"{BASE_URL}/schedule"
params = {
    "sportId": 1,
    "startDate": TEST_DATE,
    "endDate": TEST_DATE,
    "hydrate": "team,linescore,flags,venue,decisions"
}

print(f"Fetching schedule for {TEST_DATE}...")
# Added verify=False to bypass SSL errors in local environment
response = requests.get(url, params=params, verify=False)
schedule_data = response.json()

if 'dates' in schedule_data and len(schedule_data['dates']) > 0:
    games = schedule_data['dates'][0]['games']
    print(f"✅ Success: Found {len(games)} games.")
    
    # Pick a sample game for later tests
    sample_game = games[0]
    print("Example Game Structure:")
    print_structure(sample_game)
    SAMPLE_GAME_PK = sample_game['gamePk']
    SAMPLE_HOME_TEAM_ID = sample_game['teams']['home']['team']['id']
    
    print(f"\nSample Game Info:")
    print(f"Game PK: {SAMPLE_GAME_PK}")
    print(f"Matchup: {sample_game['teams']['away']['team']['name']} @ {sample_game['teams']['home']['team']['name']}")
    print(f"Status: {sample_game['status']['detailedState']}")
    print(f"Game Type: {sample_game['gameType']}")
else:
    print("❌ Error: No games found.")
# Out:
# Fetching schedule for 2025-05-15...
# ✅ Success: Found 6 games.
# Example Game Structure:
# gamePk: 777909 (int)
# gameGuid: f78bf3a9-58a8-4578-a852-8819c1eeaa0f (str)
# link: /api/v1.1/game/777909/feed/live (str)
# gameType: R (str)
# season: 2025 (str)
# gameDate: 2025-05-15T16:15:00Z (str)
# officialDate: 2025-05-15 (str)
# status (dict):
#   abstractGameState: Final (str)
#   codedGameState: F (str)
#   detailedState: Final (str)
#   statusCode: F (str)
#   startTimeTBD: False (bool)
#   abstractGameCode: F (str)
# teams (dict):
#   away (dict):
#     team (dict):
#       springLeague (dict):
#         id: 115 (int)
#         name: Grapefruit League (str)
#         link: /api/v1/league/115 (str)
#         abbreviation: GL (str)
#       allStarStatus: N (str)
#       id: 120 (int)
#       name: Washington Nationals (str)
#       link: /api/v1/teams/120 (str)
#       season: 2025 (int)
#       venue (dict):
#         id: 3309 (int)
#         name: Nationals Park (str)
#         link: /api/v1/venues/3309 (str)
#       springVenue (dict):
#         id: 5000 (int)
#         link: /api/v1/venues/5000 (str)
#       teamCode: was (str)
#       fileCode: was (str)
#       abbreviation: WSH (str)
#       teamName: Nationals (str)
#       locationName: Washington (str)
#       firstYearOfPlay: 1968 (str)
#       league (dict):
#         id: 104 (int)
#         name: National League (str)
#         link: /api/v1/league/104 (str)
#       division (dict):
#         id: 204 (int)
#         name: National League East (str)
#         link: /api/v1/divisions/204 (str)
#       sport (dict):
#         id: 1 (int)
#         link: /api/v1/sports/1 (str)
#         name: Major League Baseball (str)
#       shortName: Washington (str)
#       franchiseName: Washington (str)
#       clubName: Nationals (str)
#       active: True (bool)
#     leagueRecord (dict):
#       wins: 18 (int)
#       losses: 27 (int)
#       pct: .400 (str)
#     score: 2 (int)
#     isWinner: False (bool)
#     splitSquad: False (bool)
#     seriesNumber: 14 (int)
#     springLeague (dict):
#       id: 115 (int)
#       name: Grapefruit League (str)
#       link: /api/v1/league/115 (str)
#       abbreviation: GL (str)
#   home (dict):
#     team (dict):
#       springLeague (dict):
#         id: 115 (int)
#         name: Grapefruit League (str)
#         link: /api/v1/league/115 (str)
#         abbreviation: GL (str)
#       allStarStatus: N (str)
#       id: 144 (int)
#       name: Atlanta Braves (str)
#       link: /api/v1/teams/144 (str)
#       season: 2025 (int)
#       venue (dict):
#         id: 4705 (int)
#         name: Truist Park (str)
#         link: /api/v1/venues/4705 (str)
#       springVenue (dict):
#         id: 5380 (int)
#         link: /api/v1/venues/5380 (str)
#       teamCode: atl (str)
#       fileCode: atl (str)
#       abbreviation: ATL (str)
#       teamName: Braves (str)
#       locationName: Atlanta (str)
#       firstYearOfPlay: 1871 (str)
#       league (dict):
#         id: 104 (int)
#         name: National League (str)
#         link: /api/v1/league/104 (str)
#       division (dict):
#         id: 204 (int)
#         name: National League East (str)
#         link: /api/v1/divisions/204 (str)
#       sport (dict):
#         id: 1 (int)
#         link: /api/v1/sports/1 (str)
#         name: Major League Baseball (str)
#       shortName: Atlanta (str)
#       franchiseName: Atlanta (str)
#       clubName: Braves (str)
#       active: True (bool)
#     leagueRecord (dict):
#       wins: 22 (int)
#       losses: 22 (int)
#       pct: .500 (str)
#     score: 5 (int)
#     isWinner: True (bool)
#     splitSquad: False (bool)
#     seriesNumber: 14 (int)
#     springLeague (dict):
#       id: 115 (int)
#       name: Grapefruit League (str)
#       link: /api/v1/league/115 (str)
#       abbreviation: GL (str)
# linescore (dict):
#   currentInning: 9 (int)
#   currentInningOrdinal: 9th (str)
#   inningState: Top (str)
#   inningHalf: Top (str)
#   isTopInning: True (bool)
#   scheduledInnings: 9 (int)
#   innings (list) [9 items]:
#     Sample item:
#       num: 1 (int)
#       ordinalNum: 1st (str)
#       home (dict):
#         runs: 0 (int)
#         hits: 0 (int)
#         errors: 0 (int)
#         leftOnBase: 0 (int)
#       away (dict):
#         runs: 0 (int)
#         hits: 0 (int)
#         errors: 0 (int)
#         leftOnBase: 1 (int)
#   teams (dict):
#     home (dict):
#       runs: 5 (int)
#       hits: 9 (int)
#       errors: 1 (int)
#       leftOnBase: 7 (int)
#       isWinner: True (bool)
#     away (dict):
#       runs: 2 (int)
#       hits: 6 (int)
#       errors: 1 (int)
#       leftOnBase: 6 (int)
#       isWinner: False (bool)
#   defense (dict):
#     pitcher (dict):
#       id: 628452 (int)
#       fullName: Raisel Iglesias (str)
#       link: /api/v1/people/628452 (str)
#     catcher (dict):
#       id: 686948 (int)
#       fullName: Drake Baldwin (str)
#       link: /api/v1/people/686948 (str)
#     first (dict):
#       id: 621566 (int)
#       fullName: Matt Olson (str)
#       link: /api/v1/people/621566 (str)
#     second (dict):
#       id: 645277 (int)
#       fullName: Ozzie Albies (str)
#       link: /api/v1/people/645277 (str)
#     third (dict):
#       id: 663586 (int)
#       fullName: Austin Riley (str)
#       link: /api/v1/people/663586 (str)
#     shortstop (dict):
#       id: 669397 (int)
#       fullName: Nick Allen (str)
#       link: /api/v1/people/669397 (str)
#     left (dict):
#       id: 657077 (int)
#       fullName: Alex Verdugo (str)
#       link: /api/v1/people/657077 (str)
#     center (dict):
#       id: 671739 (int)
#       fullName: Michael Harris II (str)
#       link: /api/v1/people/671739 (str)
#     right (dict):
#       id: 642201 (int)
#       fullName: Eli White (str)
#       link: /api/v1/people/642201 (str)
#     batter (dict):
#       id: 657077 (int)
#       fullName: Alex Verdugo (str)
#       link: /api/v1/people/657077 (str)
#     onDeck (dict):
#       id: 686948 (int)
#       fullName: Drake Baldwin (str)
#       link: /api/v1/people/686948 (str)
#     inHole (dict):
#       id: 542303 (int)
#       fullName: Marcell Ozuna (str)
#       link: /api/v1/people/542303 (str)
#     battingOrder: 1 (int)
#     team (dict):
#       id: 144 (int)
#       name: Atlanta Braves (str)
#       link: /api/v1/teams/144 (str)
#   offense (dict):
#     batter (dict):
#       id: 677588 (int)
#       fullName: José Tena (str)
#       link: /api/v1/people/677588 (str)
#     onDeck (dict):
#       id: 696285 (int)
#       fullName: Jacob Young (str)
#       link: /api/v1/people/696285 (str)
#     inHole (dict):
#       id: 682928 (int)
#       fullName: CJ Abrams (str)
#       link: /api/v1/people/682928 (str)
#     pitcher (dict):
#       id: 605347 (int)
#       fullName: Jorge López (str)
#       link: /api/v1/people/605347 (str)
#     battingOrder: 8 (int)
#     team (dict):
#       id: 120 (int)
#       name: Washington Nationals (str)
#       link: /api/v1/teams/120 (str)
#   balls: 1 (int)
#   strikes: 0 (int)
#   outs: 3 (int)
# decisions (dict):
#   winner (dict):
#     id: 700363 (int)
#     fullName: AJ Smith-Shawver (str)
#     link: /api/v1/people/700363 (str)
#   loser (dict):
#     id: 592866 (int)
#     fullName: Trevor Williams (str)
#     link: /api/v1/people/592866 (str)
#   save (dict):
#     id: 628452 (int)
#     fullName: Raisel Iglesias (str)
#     link: /api/v1/people/628452 (str)
# venue (dict):
#   id: 4705 (int)
#   name: Truist Park (str)
#   link: /api/v1/venues/4705 (str)
#   active: True (bool)
#   season: 2025 (str)
# content (dict):
#   link: /api/v1/game/777909/content (str)
# isTie: False (bool)
# gameNumber: 1 (int)
# publicFacing: True (bool)
# doubleHeader: N (str)
# gamedayType: P (str)
# tiebreaker: N (str)
# calendarEventID: 14-777909-2025-05-15 (str)
# seasonDisplay: 2025 (str)
# dayNight: day (str)
# scheduledInnings: 9 (int)
# reverseHomeAwayStatus: False (bool)
# inningBreakLength: 120 (int)
# gamesInSeries: 4 (int)
# seriesGameNumber: 4 (int)
# seriesDescription: Regular Season (str)
# flags (dict):
#   noHitter: False (bool)
#   perfectGame: False (bool)
#   awayTeamNoHitter: False (bool)
#   awayTeamPerfectGame: False (bool)
#   homeTeamNoHitter: False (bool)
#   homeTeamPerfectGame: False (bool)
# recordSource: S (str)
# ifNecessary: N (str)
# ifNecessaryDescription: Normal Game (str)
#
# Sample Game Info:
# Game PK: 777909
# Matchup: Washington Nationals @ Atlanta Braves
# Status: Final
# Game Type: R

# %% [markdown]
# ## 2. Full Game Feed Test (The "Firehose")
#
# **Goal:** Retrieve the complete data package for a single game, including every play, pitch, and stat.
#
# **Endpoint:** `/game/{gamePk}/feed/live`
#
# **Structure:**
# - `gameData`: Static metadata (teams, venue, start time, weather, players involved).
# - `liveData`: Dynamic data.
#     - `linescore`: Inning-by-inning scores.
#     - `boxscore`: Final stats for every player.
#     - `plays`: Detailed play-by-play log (used as a fallback if Statcast fails).
#
# This endpoint provides the "source of truth" for game outcomes and traditional stats.

# %%
url = f"https://statsapi.mlb.com/api/v1.1/game/{SAMPLE_GAME_PK}/feed/live"

print(f"Fetching game feed for Game PK {SAMPLE_GAME_PK}...")
response = requests.get(url, verify=False)
game_feed = response.json()

if 'gameData' in game_feed and 'liveData' in game_feed:
    print("✅ Success: Game feed structure valid.")
    
    # Check Boxscore
    boxscore = game_feed['liveData']['boxscore']
    home_batters = boxscore['teams']['home']['batters']
    away_batters = boxscore['teams']['away']['batters']
    print(f"Boxscore: {len(home_batters)} home batters, {len(away_batters)} away batters.")
    
    # Check Linescore
    linescore = game_feed['liveData']['linescore']
    print(f"Linescore: {linescore['teams']['home']['runs']} - {linescore['teams']['away']['runs']}")
    
    # Check for Play-by-Play (Statcast fallback)
    plays = game_feed['liveData']['plays']['allPlays']
    print(f"Play-by-Play: {len(plays)} events found.")
    if len(plays) > 0:
        print("Example Play Structure:")
        print_structure(plays[0])
else:
    print("❌ Error: Invalid game feed structure.")
# Out:
# Fetching game feed for Game PK 777909...
# ✅ Success: Game feed structure valid.
# Boxscore: 13 home batters, 14 away batters.
# Linescore: 5 - 2
# Play-by-Play: 71 events found.
# Example Play Structure:
# result (dict):
#   type: atBat (str)
#   event: Strikeout (str)
#   eventType: strikeout (str)
#   description: CJ Abrams strikes out swinging. (str)
#   rbi: 0 (int)
#   awayScore: 0 (int)
#   homeScore: 0 (int)
#   isOut: True (bool)
# about (dict):
#   atBatIndex: 0 (int)
#   halfInning: top (str)
#   isTopInning: True (bool)
#   inning: 1 (int)
#   startTime: 2025-05-15T16:15:22.772Z (str)
#   endTime: 2025-05-15T16:15:56.479Z (str)
#   isComplete: True (bool)
#   isScoringPlay: False (bool)
#   hasReview: False (bool)
#   hasOut: True (bool)
#   captivatingIndex: 14 (int)
# count (dict):
#   balls: 0 (int)
#   strikes: 3 (int)
#   outs: 1 (int)
# matchup (dict):
#   batter (dict):
#     id: 682928 (int)
#     fullName: CJ Abrams (str)
#     link: /api/v1/people/682928 (str)
#   batSide (dict):
#     code: L (str)
#     description: Left (str)
#   pitcher (dict):
#     id: 700363 (int)
#     fullName: AJ Smith-Shawver (str)
#     link: /api/v1/people/700363 (str)
#   pitchHand (dict):
#     code: R (str)
#     description: Right (str)
#   batterHotColdZones (list) [0 items]:
#   pitcherHotColdZones (list) [0 items]:
#   splits (dict):
#     batter: vs_RHP (str)
#     pitcher: vs_LHB (str)
#     menOnBase: Empty (str)
# pitchIndex (list) [3 items]:
#   Sample item:
#     3 (int)
# actionIndex (list) [3 items]:
#   Sample item:
#     0 (int)
# runnerIndex (list) [1 items]:
#   Sample item:
#     0 (int)
# runners (list) [1 items]:
#   Sample item:
#     movement (dict):
#       originBase: None (NoneType)
#       start: None (NoneType)
#       end: None (NoneType)
#       outBase: 1B (str)
#       isOut: True (bool)
#       outNumber: 1 (int)
#     details (dict):
#       event: Strikeout (str)
#       eventType: strikeout (str)
#       movementReason: None (NoneType)
#       runner (dict):
#         id: 682928 (int)
#         fullName: CJ Abrams (str)
#         link: /api/v1/people/682928 (str)
#       responsiblePitcher: None (NoneType)
#       isScoringEvent: False (bool)
#       rbi: False (bool)
#       earned: False (bool)
#       teamUnearned: False (bool)
#       playIndex: 5 (int)
#     credits (list) [1 items]:
#       Sample item:
#         player (dict):
#           id: 686948 (int)
#           link: /api/v1/people/686948 (str)
#         position (dict):
#           code: 2 (str)
#           name: Catcher (str)
#           type: Catcher (str)
#           abbreviation: C (str)
#         credit: f_putout (str)
# playEvents (list) [6 items]:
#   Sample item:
#     details (dict):
#       description: Status Change - Pre-Game (str)
#       event: Game Advisory (str)
#       eventType: game_advisory (str)
#       awayScore: 0 (int)
#       homeScore: 0 (int)
#       isScoringPlay: False (bool)
#       isOut: False (bool)
#       hasReview: False (bool)
#     count (dict):
#       balls: 0 (int)
#       strikes: 0 (int)
#       outs: 0 (int)
#     index: 0 (int)
#     startTime: 2025-05-15T13:49:36.116Z (str)
#     endTime: 2025-05-15T15:50:02.403Z (str)
#     isPitch: False (bool)
#     type: action (str)
#     player (dict):
#       id: 682928 (int)
#       link: /api/v1/people/682928 (str)
# playEndTime: 2025-05-15T16:15:56.479Z (str)
# atBatIndex: 0 (int)

# %% [markdown]
# ## 3. Player Stats Endpoint Test
#
# **Goal:** Fetch daily performance stats for **every** player who appeared in a game, not just the stars.
#
# **Endpoint:** `/stats`
#
# **Critical Configuration:**
# - `qualified=false`: **Most Important.** By default, APIs often filter for "qualified" players (e.g., 3.1 PA/game). We need this set to `false` to capture relievers, pinch hitters, and defensive replacements.
# - `stats=gameLog`: Requests stats for specific games rather than season totals.
# - `limit=1000`: Ensures we don't hit pagination limits on busy days.

# %%
url = f"{BASE_URL}/stats"
params = {
    "stats": "byDateRange", # Changed from 'gameLog' to 'byDateRange' to get all players
    "group": "hitting", 
    "gameType": "R",
    "startDate": TEST_DATE, # 'byDateRange' requires start/end dates
    "endDate": TEST_DATE,
    "limit": 1000,
    "qualified": "false"
}

print(f"Fetching hitting stats for {TEST_DATE}...")
response = requests.get(url, params=params, verify=False)
stats_data = response.json()

if 'stats' in stats_data and len(stats_data['stats']) > 0:
    stat_group = stats_data['stats'][0]
    if 'splits' in stat_group:
        splits = stat_group['splits']
        print(f"✅ Success: Found {len(splits)} player records.")
        
        # Verify we have some data
        if len(splits) > 0:
            sample = splits[0]
            print("\nSample Player Stat:")
            print(f"Player: {sample['player']['fullName']} (ID: {sample['player']['id']})")
            print(f"Team: {sample['team']['name']}")
            print("Stats Structure:")
            print(json.dumps(sample['stat'], indent=2))
    else:
        print("⚠️ Warning: Stats group found but no 'splits' key.")
else:
    print("❌ Error: No stats found. Response keys:", list(stats_data.keys()))
# Out:
# Fetching hitting stats for 2025-05-15...
# ✅ Success: Found 75 player records.
#
# Sample Player Stat:
# Player: Hyeseong Kim (ID: 808975)
# Team: Los Angeles Dodgers
# Stats Structure:
# {
#   "gamesPlayed": 1,
#   "groundOuts": 0,
#   "airOuts": 0,
#   "runs": 4,
#   "doubles": 1,
#   "triples": 0,
#   "homeRuns": 0,
#   "strikeOuts": 0,
#   "baseOnBalls": 2,
#   "intentionalWalks": 0,
#   "hits": 3,
#   "hitByPitch": 0,
#   "avg": "1.000",
#   "atBats": 3,
#   "obp": "1.000",
#   "slg": "1.333",
#   "ops": "2.333",
#   "caughtStealing": 0,
#   "stolenBases": 1,
#   "stolenBasePercentage": "1.000",
#   "caughtStealingPercentage": ".000",
#   "groundIntoDoublePlay": 0,
#   "groundIntoTriplePlay": 0,
#   "numberOfPitches": 21,
#   "plateAppearances": 5,
#   "totalBases": 4,
#   "rbi": 2,
#   "leftOnBase": 0,
#   "sacBunts": 0,
#   "sacFlies": 0,
#   "babip": "1.000",
#   "groundOutsToAirouts": "-.--",
#   "catchersInterference": 0,
#   "atBatsPerHomeRun": "-.--"
# }

# %%
url = f"{BASE_URL}/stats"
params = {
    "stats": "byDateRange", # Changed from 'gameLog' to 'byDateRange' to get all players
    "group": "pitching", 
    "gameType": "R",
    "startDate": TEST_DATE, # 'byDateRange' requires start/end dates
    "endDate": TEST_DATE,
    "limit": 1000,
    "qualified": "false"
}

print(f"Fetching hitting stats for {TEST_DATE}...")
response = requests.get(url, params=params, verify=False)
stats_data = response.json()

if 'stats' in stats_data and len(stats_data['stats']) > 0:
    stat_group = stats_data['stats'][0]
    if 'splits' in stat_group:
        splits = stat_group['splits']
        print(f"✅ Success: Found {len(splits)} player records.")
        
        # Verify we have some data
        if len(splits) > 0:
            sample = splits[0]
            print("\nSample Player Stat:")
            print(f"Player: {sample['player']['fullName']} (ID: {sample['player']['id']})")
            print(f"Team: {sample['team']['name']}")
            print("Stats Structure:")
            print(json.dumps(sample['stat'], indent=2))
    else:
        print("⚠️ Warning: Stats group found but no 'splits' key.")
else:
    print("❌ Error: No stats found. Response keys:", list(stats_data.keys()))
# Out:
# Fetching hitting stats for 2025-05-15...
# ✅ Success: Found 34 player records.
#
# Sample Player Stat:
# Player: Shawn Armstrong (ID: 542888)
# Team: Texas Rangers
# Stats Structure:
# {
#   "gamesPlayed": 1,
#   "gamesStarted": 0,
#   "groundOuts": 0,
#   "airOuts": 3,
#   "runs": 0,
#   "doubles": 0,
#   "triples": 0,
#   "homeRuns": 0,
#   "strikeOuts": 0,
#   "baseOnBalls": 1,
#   "intentionalWalks": 0,
#   "hits": 0,
#   "hitByPitch": 0,
#   "avg": ".000",
#   "atBats": 3,
#   "obp": ".250",
#   "slg": ".000",
#   "ops": ".250",
#   "caughtStealing": 0,
#   "stolenBases": 0,
#   "stolenBasePercentage": ".---",
#   "caughtStealingPercentage": ".---",
#   "groundIntoDoublePlay": 0,
#   "numberOfPitches": 13,
#   "era": "0.00",
#   "inningsPitched": "1.0",
#   "outsPitched": 3,
#   "wins": 0,
#   "losses": 0,
#   "saves": 1,
#   "saveOpportunities": 1,
#   "holds": 0,
#   "blownSaves": 0,
#   "earnedRuns": 0,
#   "whip": "1.00",
#   "battersFaced": 4,
#   "outs": 3,
#   "gamesPitched": 1,
#   "completeGames": 0,
#   "shutouts": 0,
#   "balls": 6,
#   "strikes": 7,
#   "strikePercentage": ".540",
#   "hitBatsmen": 0,
#   "balks": 0,
#   "wildPitches": 0,
#   "totalBases": 0,
#   "groundOutsToAirouts": "0.00",
#   "rbi": 0,
#   "winPercentage": ".---",
#   "pitchesPerInning": "13.00",
#   "gamesFinished": 1,
#   "strikeoutWalkRatio": "0.00",
#   "strikeoutsPer9Inn": "0.00",
#   "walksPer9Inn": "9.00",
#   "hitsPer9Inn": "0.00",
#   "runsScoredPer9": "0.00",
#   "homeRunsPer9": "0.00",
#   "inheritedRunners": 0,
#   "inheritedRunnersScored": 0,
#   "catchersInterference": 0,
#   "sacBunts": 0,
#   "sacFlies": 0
# }

# %% [markdown]
# ## 4. Transactions Endpoint Test
#
# **Goal:** Track player movement to maintain accurate rosters and injury status.
#
# **Endpoint:** `/transactions`
#
# **Use Case:**
# We use this to detect:
# - Roster moves (Call-ups, options)
# - Injuries (IL placements)
# - Trades
# - DFAs and Releases
#
# This data is vital for feature engineering (e.g., "Is the starting pitcher coming off the IL?").

# %%
url = f"{BASE_URL}/transactions"
params = {
    "sportId": 1,
    "startDate": TEST_DATE,
    "endDate": TEST_DATE
}

print(f"Fetching transactions for {TEST_DATE}...")
response = requests.get(url, params=params, verify=False)
trans_data = response.json()

if 'transactions' in trans_data:
    print(f"✅ Success: Found {len(trans_data['transactions'])} transactions.")
    if len(trans_data['transactions']) > 0:
        print("Sample Transaction Structure:")
        print(json.dumps(trans_data['transactions'][0], indent=2))
else:
    print("⚠️ Note: No transactions found (this might be normal for some dates).")
# Out:
# Fetching transactions for 2025-05-15...
# ✅ Success: Found 30 transactions.
# Sample Transaction Structure:
# {
#   "id": 837759,
#   "person": {
#     "id": 666139,
#     "fullName": "Josh Lowe",
#     "link": "/api/v1/people/666139"
#   },
#   "toTeam": {
#     "id": 139,
#     "name": "Tampa Bay Rays",
#     "link": "/api/v1/teams/139"
#   },
#   "date": "2025-05-15",
#   "effectiveDate": "2025-05-15",
#   "resolutionDate": "2025-05-15",
#   "typeCode": "SC",
#   "typeDesc": "Status Change",
#   "description": "Tampa Bay Rays activated RF Josh Lowe from the 10-day injured list."
# }

# %% [markdown]
# ## 5. Rosters Endpoint Test
#
# **Goal:** Get a snapshot of who is actually available to play for a team on a given day.
#
# **Endpoint:** `/teams/{teamId}/roster`
#
# **Parameters:**
# - `rosterType=active`: Fetches the 26-man active roster.
# - `date`: Allows us to look up historical rosters (time-travel), which is essential for training models on past data.

# %%
url = f"{BASE_URL}/teams/{SAMPLE_HOME_TEAM_ID}/roster"
params = {
    "rosterType": "active",
    "date": TEST_DATE
}

print(f"Fetching roster for Team ID {SAMPLE_HOME_TEAM_ID} on {TEST_DATE}...")
response = requests.get(url, params=params, verify=False)
roster_data = response.json()

if 'roster' in roster_data:
    print(f"✅ Success: Found {len(roster_data['roster'])} players on active roster.")
    if len(roster_data['roster']) > 0:
        print("Sample Roster Entry Structure:")
        print(json.dumps(roster_data['roster'][0], indent=2))
else:
    print("❌ Error: Roster fetch failed.")
# Out:
# Fetching roster for Team ID 144 on 2025-05-15...
# ✅ Success: Found 26 players on active roster.
# Sample Roster Entry Structure:
# {
#   "person": {
#     "id": 700363,
#     "fullName": "AJ Smith-Shawver",
#     "link": "/api/v1/people/700363"
#   },
#   "jerseyNumber": "32",
#   "position": {
#     "code": "1",
#     "name": "Pitcher",
#     "type": "Pitcher",
#     "abbreviation": "P"
#   },
#   "status": {
#     "code": "A",
#     "description": "Active"
#   },
#   "parentTeamId": 144
# }

# %% [markdown]
# ## 6. Statcast Data Test (pybaseball)
#
# **Goal:** Retrieve advanced pitch-by-pitch physics data (velocity, spin rate, exit velo, etc.).
#
# **Source:** Baseball Savant (via `pybaseball` library)
#
# **Why pybaseball?**
# While the MLB API contains some pitch data, Baseball Savant provides the "Statcast" specific metrics (effective velocity, break angle, catch probability) in a format that is easier to analyze for ML.
#
# **Note:** This step fetches data from external servers and may take a few seconds.

# %%
import requests
import urllib3

# Suppress warnings
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# Monkey-patch requests to force verify=False for pybaseball
# This is necessary because pybaseball doesn't expose a verify parameter
_orig_get = requests.get
_orig_session_request = requests.Session.request

def patched_get(*args, **kwargs):
    kwargs['verify'] = False
    return _orig_get(*args, **kwargs)

def patched_session_request(self, *args, **kwargs):
    kwargs['verify'] = False
    return _orig_session_request(self, *args, **kwargs)

requests.get = patched_get
requests.Session.request = patched_session_request

try:
    from pybaseball import statcast_single_game
    print("✅ pybaseball is installed.")
    
    # Ensure we have game PKs from the schedule step
    if 'games' in locals() and len(games) > 0:
        game_pks = [g['gamePk'] for g in games]
        print(f"Found {len(game_pks)} games to fetch. Processing individually...")
        
        statcast_frames = []
        
        for pk in game_pks:
            print(f"  Fetching Statcast for Game {pk}...", end=" ")
            try:
                # Fetch data for single game
                game_df = statcast_single_game(pk)
                
                if not game_df.empty:
                    statcast_frames.append(game_df)
                    print(f"✅ {len(game_df)} records")
                else:
                    print("⚠️ No data")
                
                # Sleep briefly to be nice to the API
                time.sleep(0.5)
                
            except Exception as e:
                print(f"❌ Error: {e}")

        if statcast_frames:
            df = pd.concat(statcast_frames)
            print(f"\n✅ Success: Fetched total {len(df)} pitch records.")
            print("\nSample Data:")
            print(df[['game_pk', 'batter', 'pitcher', 'events', 'launch_speed', 'launch_angle']].head(3))
        else:
            print("\n⚠️ Warning: No data returned for any game.")
            
    else:
        print("⚠️ No games found in 'games' variable. Run the Schedule cell first.")
        
except ImportError:
    print("⚠️ pybaseball not installed. Skipping this test.")
    print("To install: !pip install pybaseball")
except Exception as e:
    print(f"❌ Error fetching Statcast data: {e}")
finally:
    # Restore original requests methods to avoid side effects later
    requests.get = _orig_get
    requests.Session.request = _orig_session_request
# Out:
# ✅ pybaseball is installed.
# Found 6 games to fetch. Processing individually...
#   Fetching Statcast for Game 777909...
# /Users/VTNX82W/Documents/personalDev/hanks_tank_ml/.venv/lib/python3.13/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# ✅ 267 records
#   Fetching Statcast for Game 777911...
# /Users/VTNX82W/Documents/personalDev/hanks_tank_ml/.venv/lib/python3.13/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# ✅ 289 records
#   Fetching Statcast for Game 777912...
# /Users/VTNX82W/Documents/personalDev/hanks_tank_ml/.venv/lib/python3.13/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# ✅ 246 records
#   Fetching Statcast for Game 777913...
# /Users/VTNX82W/Documents/personalDev/hanks_tank_ml/.venv/lib/python3.13/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# ✅ 268 records
#   Fetching Statcast for Game 777910...
# /Users/VTNX82W/Documents/personalDev/hanks_tank_ml/.venv/lib/python3.13/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# ✅ 200 records
#   Fetching Statcast for Game 777946...
# /Users/VTNX82W/Documents/personalDev/hanks_tank_ml/.venv/lib/python3.13/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# ✅ 320 records
#
# ✅ Success: Fetched total 1590 pitch records.
#
# Sample Data:
#      game_pk  batter  pitcher                     events  launch_speed  \
# 178   777909  677588   628452  grounded_into_double_play          70.3
# 191   777909  677588   628452                        NaN           NaN
# 197   777909  669743   628452                  force_out          78.2
#
#      launch_angle
# 178         -15.0
# 191           NaN
# 197         -12.0
